# %% [markdown]
# # CASO 3 - PARK RAMIREZ

# %% [markdown]
# Analise de onde adicionar os pontos

# %%
import numpy as np 
from scipy.integrate import odeint
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import pywt
import statistics


ai=np.linspace(0.4,0.6,3)
for aix in range(len(ai)):
    #Condições iniciais
    ns=32 #numero de grids iniciais
    x10 = 0
    x20 = 0
    x30 = 1
    x40 = 5
    x50 = 1
    
    i=1
    tm=[]
    xm=[]
    #variáveis para armazenar dados para plot
    tg=[0]*i
    data2=[0]*i
    t = np.linspace(0,15,ns+1)
    w0 = np.zeros(ns)
    err=1
    err1=1
    tol=1e-9
    
    a=ai[aix]
    print(a)
    while err>tol:
        
        #t = np.linspace(0,15,ns+1)
        #w0 = np.zeros(ns)
        def state(y,t,w):
            x1,x2,x3,x4,x5 = y
            f = [ (4.75*(21.87*x4/((x4+0.4)*(x4+62.5)))/(0.12+(21.87*x4/((x4+0.4)*(x4+62.5)))))*(x2-x1)-w*x1/x5,
                (x4*np.exp(-5*x4)/(0.1+x4))*x3-w*x2/x5,
                (21.87*x4/((x4+0.4)*(x4+62.5)))*x3-w*x3/x5,
                -7.3*(21.87*x4/((x4+0.4)*(x4+62.5)))*x3+w*(20-x4)/x5,
                w];
            return f
    
        def objective(w0):
            y0 = [x10,x20,x30,x40,x50]
            res=[];
            for ks in range(0, ns):
                sol = odeint(state,y0,np.linspace(t[ks],t[ks+1],20), args=(w0[ks],), Dfun=None, col_deriv=0, full_output=0, ml=None, mu=None, rtol=None, atol=None, tcrit=None, h0=0.0, hmax=0.0, hmin=0.0, ixpr=0, mxstep=0, mxhnil=0, mxordn=12, mxords=5, printmessg=0, tfirst=False)
                y0=sol[-1]
            obj = -sol[-1][0]*sol[-1][4]
            return obj
        
        res = minimize(objective,w0,method='SLSQP', jac=None, bounds=[(0,2)]*ns, constraints=(), tol=None, callback=None,options={'maxiter':100000000,'ftol':1e-10,'disp':True})
        y0 = [x10,x20,x30,x40,x50]
        err=abs((res.fun-err1)/err1)
        err1=res.fun
        w0 = res.x
        print(err)
            
        db1 = pywt.Wavelet('db1')
        maxlevel=pywt.dwt_max_level(len(res.x), db1)
        # mesmo se eu não usar o dwt_max_level o wavedec já calcula no max de níveis possiveis
        
        cD = pywt.wavedec(res.x, db1,mode='symmetric',level=maxlevel)
        t1=t
        Cdvr=statistics.pstdev(cD[-1])
        Thr=Cdvr*(2*np.log(len(cD[-1])))**(1/2)
        
        #cX=[x for x in abs(cD[-1]) if x > abs(Thr)]
        indx = np.where(abs(cD[-1])>abs(Thr))
        z=0
        for x in range(len(indx[0]),0,-1):
            x=x-1
            if indx[0][x]!=0:
                t=np.insert(t,indx[0][x]*2,(t[indx[0][x]*2-1]*a+t[indx[0][x]*2]*(1-a)))
                w0=np.insert(w0,indx[0][x]*2,w0[indx[0][x]*2-1])
                t=np.insert(t,indx[0][x]*2-1,(t[indx[0][x]*2-2]*a+t[indx[0][x]*2-1]*(1-a)))
                w0=np.insert(w0,indx[0][x]*2-1,w0[indx[0][x]*2+z-2])
            
            else:
                t=np.insert(t,indx[0][x]*2+1,(t[indx[0][x]*2]*a+t[indx[0][x]*2+1]*(1-a)))
                w0=np.insert(w0,indx[0][x]*2+1,w0[indx[0][x]*2])
            
            
        # Usei isso aqui somente para verificar a integração com o controle otimo
        for ks in range(0, ns):
             #   sol = odeint(state,y0,np.linspace(t[ks],t[ks+1],5), args=(w0[ks],), Dfun=None, col_deriv=0, full_output=0, ml=None, mu=None, rtol=None, atol=None, tcrit=None, h0=0.0, hmax=0.0, hmin=0.0, ixpr=0, mxstep=0, mxhnil=0, mxordn=12, mxords=5, printmessg=0, tfirst=False)
                sol = odeint(state,y0,np.linspace(t[ks],t[ks+1],20), args=(w0[ks],))
                y0=sol[-1]
        
        #Plot u(t) vs tempo
        #plt.figure(i)
        #plt.step(t1[1:ns+1],res.x,'k',LineWidth=1)
        #plt.axis([0, 15, 0, 2])
        #plt.xlabel("Time (h)")
        #plt.ylabel("u(t)")
        #plt.show()
        print(ns)
        #atualização do ns
        ns=len(t)-1
        i=i+1
    color=['b', 'g', 'r', 'k']
    plt.figure(1)
    plt.step(t1[1:ns+1],res.x,color[aix],LineWidth=1)
# Out:
# 0.4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615001873156565
#             Iterations: 84
#             Function evaluations: 2972
#             Gradient evaluations: 84
# 33.615001873156565
# 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.6150023535359
#             Iterations: 28
#             Function evaluations: 1095
#             Gradient evaluations: 28
# 1.4728784514604775e-08
# 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615003052456444
#             Iterations: 23
#             Function evaluations: 949
#             Gradient evaluations: 23
# 2.142941879858248e-08
# 36
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.6150914666214
#             Iterations: 36
#             Function evaluations: 1525
#             Gradient evaluations: 36
# 2.710843375185871e-06
# 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615091953748895
#             Iterations: 6
#             Function evaluations: 291
#             Gradient evaluations: 6
# 1.4935647026969667e-08
# 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61509204581397
#             Iterations: 9
#             Function evaluations: 458
#             Gradient evaluations: 9
# 2.8227751784659738e-09
# 42
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615091873658585
#             Iterations: 3
#             Function evaluations: 161
#             Gradient evaluations: 3
# 5.278396310030977e-09
# 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61509176387927
#             Iterations: 6
#             Function evaluations: 320
#             Gradient evaluations: 6
# 3.365905420501864e-09
# 46
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61509166007809
#             Iterations: 5
#             Function evaluations: 288
#             Gradient evaluations: 5
# 3.1826118467711656e-09
# 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61509142743885
#             Iterations: 7
#             Function evaluations: 419
#             Gradient evaluations: 7
# 7.132871100954033e-09
# 50
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61509142397282
#             Iterations: 2
#             Function evaluations: 126
#             Gradient evaluations: 2
# 1.0627066530685313e-10
# 52
# 0.5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615001873156565
#             Iterations: 84
#             Function evaluations: 2972
#             Gradient evaluations: 84
# 33.615001873156565
# 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615002402541045
#             Iterations: 27
#             Function evaluations: 1050
#             Gradient evaluations: 27
# 1.623131837989652e-08
# 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61506034695712
#             Iterations: 13
#             Function evaluations: 535
#             Gradient evaluations: 13
# 1.7766184825804376e-06
# 36
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61506071078127
#             Iterations: 4
#             Function evaluations: 187
#             Gradient evaluations: 4
# 1.1155096621124478e-08
# 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615061199297976
#             Iterations: 5
#             Function evaluations: 253
#             Gradient evaluations: 5
# 1.497825525312289e-08
# 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512813580007
#             Iterations: 36
#             Function evaluations: 1672
#             Gradient evaluations: 36
# 2.0523187641737647e-06
# 42
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512865032632
#             Iterations: 17
#             Function evaluations: 860
#             Gradient evaluations: 17
# 1.577569301644416e-08
# 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512835577429
#             Iterations: 9
#             Function evaluations: 477
#             Gradient evaluations: 9
# 9.03114729131321e-09
# 46
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615128241818326
#             Iterations: 4
#             Function evaluations: 227
#             Gradient evaluations: 4
# 3.4939602765057763e-09
# 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512822500575
#             Iterations: 3
#             Function evaluations: 181
#             Gradient evaluations: 3
# 5.154840377081365e-10
# 50
# 0.6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615001873156565
#             Iterations: 84
#             Function evaluations: 2972
#             Gradient evaluations: 84
# 33.615001873156565
# 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61500248536655
#             Iterations: 30
#             Function evaluations: 1151
#             Gradient evaluations: 30
# 1.8770809518109753e-08
# 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615003112682444
#             Iterations: 14
#             Function evaluations: 576
#             Gradient evaluations: 14
# 1.9233967311774112e-08
# 36
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615037997604915
#             Iterations: 22
#             Function evaluations: 937
#             Gradient evaluations: 22
# 1.0695973981728248e-06
# 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503843391103
#             Iterations: 10
#             Function evaluations: 469
#             Gradient evaluations: 10
# 1.3377452345789855e-08
# 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503888049444
#             Iterations: 6
#             Function evaluations: 291
#             Gradient evaluations: 6
# 1.3692561105026642e-08
# 42
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503930173469
#             Iterations: 2
#             Function evaluations: 110
#             Gradient evaluations: 2
# 1.2915521980904729e-08
# 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61508991495886
#             Iterations: 24
#             Function evaluations: 1210
#             Gradient evaluations: 24
# 1.551836982318912e-06
# 46
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61508959363323
#             Iterations: 11
#             Function evaluations: 626
#             Gradient evaluations: 11
# 9.852054066183396e-09
# 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512275774067
#             Iterations: 20
#             Function evaluations: 1081
#             Gradient evaluations: 20
# 1.0168332466867644e-06
# 50
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615122678778555
#             Iterations: 10
#             Function evaluations: 597
#             Gradient evaluations: 10
# 2.4210277370905962e-09
# 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615122641730146
#             Iterations: 4
#             Function evaluations: 250
#             Gradient evaluations: 4
# 1.1359273166056003e-09
# 54
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512263387324
#             Iterations: 1
#             Function evaluations: 68
#             Gradient evaluations: 1
# 2.4089759056479983e-10
# 56

# %% [markdown]
# Analise wavelets, com a=0.5

# %%
import numpy as np 
from scipy.integrate import odeint
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import pywt
import statistics


ai=np.linspace(0,2,3)
for aix in range(len(ai)):
    #Condições iniciais
    ns=32 #numero de grids iniciais
    x10 = 0
    x20 = 0
    x30 = 1
    x40 = 5
    x50 = 1
    
    i=1
    tm=[]
    xm=[]
    #variáveis para armazenar dados para plot
    tg=[0]*i
    data2=[0]*i
    t = np.linspace(0,15,ns+1)
    w0 = np.zeros(ns)
    err=1
    err1=1
    tol=1e-9
    
    a=0.5
    print(a)
    while err>tol:
        
        #t = np.linspace(0,15,ns+1)
        #w0 = np.zeros(ns)
        def state(y,t,w):
            x1,x2,x3,x4,x5 = y
            f = [ (4.75*(21.87*x4/((x4+0.4)*(x4+62.5)))/(0.12+(21.87*x4/((x4+0.4)*(x4+62.5)))))*(x2-x1)-w*x1/x5,
                (x4*np.exp(-5*x4)/(0.1+x4))*x3-w*x2/x5,
                (21.87*x4/((x4+0.4)*(x4+62.5)))*x3-w*x3/x5,
                -7.3*(21.87*x4/((x4+0.4)*(x4+62.5)))*x3+w*(20-x4)/x5,
                w];
            return f
    
        def objective(w0):
            y0 = [x10,x20,x30,x40,x50]
            res=[];
            for ks in range(0, ns):
                sol = odeint(state,y0,np.linspace(t[ks],t[ks+1],20), args=(w0[ks],), Dfun=None, col_deriv=0, full_output=0, ml=None, mu=None, rtol=None, atol=None, tcrit=None, h0=0.0, hmax=0.0, hmin=0.0, ixpr=0, mxstep=0, mxhnil=0, mxordn=12, mxords=5, printmessg=0, tfirst=False)
                y0=sol[-1]
            obj = -sol[-1][0]*sol[-1][4]
            return obj
        
        res = minimize(objective,w0,method='SLSQP', jac=None, bounds=[(0,2)]*ns, constraints=(), tol=None, callback=None,options={'maxiter':100000000,'ftol':1e-10,'disp':True})
        y0 = [x10,x20,x30,x40,x50]
        err=abs((res.fun-err1)/err1)
        err1=res.fun
        w0 = res.x
        print(err)
        wav=['db1','sym2','dmey']
        db1 = pywt.Wavelet(wav[aix])
        maxlevel=pywt.dwt_max_level(len(res.x), db1)
        # mesmo se eu não usar o dwt_max_level o wavedec já calcula no max de níveis possiveis
        
        cD = pywt.wavedec(res.x, db1,mode='symmetric',level=maxlevel)
        t1=t
        Cdvr=statistics.pstdev(cD[-1])
        Thr=Cdvr*(2*np.log(len(cD[-1])))**(1/2)
        ##Calculo da entropia de shannon
        sumsh=0
        for sh in range(len(cD[-1])):
            sumsh=sumsh+cD[-1][sh]**2
        p=[]
        for shp in range(len(cD[-1])):
            p.append((cD[-1][shp]**2)/sumsh)
        Es=0
        for she in range(len(p)):
            if p[she]!=0:
                Es=Es-p[she]*np.log2(p[she])
        R=sumsh/Es
        print('R=',R)
        print('Es=',Es)
        
        #cX=[x for x in abs(cD[-1]) if x > abs(Thr)]
        indx = np.where(abs(cD[-1])>abs(Thr))
        z=0
        if wav[aix]=='db1':
            for x in range(len(indx[0]),0,-1):
                x=x-1
                if indx[0][x]!=0:
                    t=np.insert(t,indx[0][x]*2,(t[indx[0][x]*2-1]*a+t[indx[0][x]*2]*(1-a)))
                    w0=np.insert(w0,indx[0][x]*2,w0[indx[0][x]*2-1])
                    t=np.insert(t,indx[0][x]*2-1,(t[indx[0][x]*2-2]*a+t[indx[0][x]*2-1]*(1-a)))
                    w0=np.insert(w0,indx[0][x]*2-1,w0[indx[0][x]*2+z-2])
                
                else:
                    t=np.insert(t,indx[0][x]*2+1,(t[indx[0][x]*2]*a+t[indx[0][x]*2+1]*(1-a)))
                    w0=np.insert(w0,indx[0][x]*2+1,w0[indx[0][x]*2])
        elif wav[aix]=='dmey':
            for x in range(len(indx[0]),0,-1):
                x=x-1
                t=np.insert(t,indx[0][x],(t[indx[0][x]-1]*a+t[indx[0][x]]*(1-a)))
                w0=np.insert(w0,indx[0][x],w0[indx[0][x]-1])
        else:
            indx = np.where(abs(cD[-1][1:-1])>abs(Thr))
            for x in range(len(indx[0]),0,-1):
                x=x-1
                if indx[0][x]!=0:
                    t=np.insert(t,indx[0][x]*2,(t[indx[0][x]*2-1]*a+t[indx[0][x]*2]*(1-a)))
                    w0=np.insert(w0,indx[0][x]*2,w0[indx[0][x]*2-1])
                    t=np.insert(t,indx[0][x]*2-1,(t[indx[0][x]*2-2]*a+t[indx[0][x]*2-1]*(1-a)))
                    w0=np.insert(w0,indx[0][x]*2-1,w0[indx[0][x]*2+z-2])
                
                else:
                    t=np.insert(t,indx[0][x]*2+1,(t[indx[0][x]*2]*a+t[indx[0][x]*2+1]*(1-a)))
                    w0=np.insert(w0,indx[0][x]*2+1,w0[indx[0][x]*2])
            
        # Usei isso aqui somente para verificar a integração com o controle otimo
        for ks in range(0, ns):
             #   sol = odeint(state,y0,np.linspace(t[ks],t[ks+1],5), args=(w0[ks],), Dfun=None, col_deriv=0, full_output=0, ml=None, mu=None, rtol=None, atol=None, tcrit=None, h0=0.0, hmax=0.0, hmin=0.0, ixpr=0, mxstep=0, mxhnil=0, mxordn=12, mxords=5, printmessg=0, tfirst=False)
                sol = odeint(state,y0,np.linspace(t[ks],t[ks+1],20), args=(w0[ks],))
                y0=sol[-1]
        
        #Plot u(t) vs tempo
        #plt.figure(i)
        #plt.step(t1[1:ns+1],res.x,'k',LineWidth=1)
        #plt.axis([0, 15, 0, 2])
        #plt.xlabel("Time (h)")
        #plt.ylabel("u(t)")
        #plt.show()
        print(ns)
        #atualização do ns
        ns=len(t)-1
        i=i+1
    color=['b', 'g', 'r', 'k']
    plt.figure(1)
    plt.step(t1[1:ns+1],res.x,color[aix],LineWidth=1)
# Out:
# 0.5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615001873156565
#             Iterations: 84
#             Function evaluations: 2972
#             Gradient evaluations: 84
# 33.615001873156565
# R= 1.4958001858993655
# Es= 1.4691066798073908
# 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615002402541045
#             Iterations: 27
#             Function evaluations: 1050
#             Gradient evaluations: 27
# 1.623131837989652e-08
# R= 1.4944851533890668
# Es= 1.4698610521441067
# 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61506034695712
#             Iterations: 13
#             Function evaluations: 535
#             Gradient evaluations: 13
# 1.7766184825804376e-06
# R= 1.4956869617500004
# Es= 1.468246206591656
# 36
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61506071078127
#             Iterations: 4
#             Function evaluations: 187
#             Gradient evaluations: 4
# 1.1155096621124478e-08
# R= 1.4957081610639484
# Es= 1.4682366552907116
# 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615061199297976
#             Iterations: 5
#             Function evaluations: 253
#             Gradient evaluations: 5
# 1.497825525312289e-08
# R= 1.495710706502846
# Es= 1.4682313770468145
# 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512813580007
#             Iterations: 36
#             Function evaluations: 1672
#             Gradient evaluations: 36
# 2.0523187641737647e-06
# R= 1.496345800464386
# Es= 1.467430369496465
# 42
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512865032632
#             Iterations: 17
#             Function evaluations: 860
#             Gradient evaluations: 17
# 1.577569301644416e-08
# R= 1.4962196932881993
# Es= 1.4675289093212174
# 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512835577429
#             Iterations: 9
#             Function evaluations: 477
#             Gradient evaluations: 9
# 9.03114729131321e-09
# R= 1.496253311628342
# Es= 1.4674361512167329
# 46
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615128241818326
#             Iterations: 4
#             Function evaluations: 227
#             Gradient evaluations: 4
# 3.4939602765057763e-09
# R= 1.4962451590622088
# Es= 1.4674417988434638
# 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61512822500575
#             Iterations: 3
#             Function evaluations: 181
#             Gradient evaluations: 3
# 5.154840377081365e-10
# R= 1.4962443656881874
# Es= 1.4674420574828777
# 50
# 0.5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615001873156565
#             Iterations: 84
#             Function evaluations: 2972
#             Gradient evaluations: 84
# 33.615001873156565
# R= 0.6421818283860564
# Es= 1.9602498735002554
# 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503121449358
#             Iterations: 113
#             Function evaluations: 4196
#             Gradient evaluations: 113
# 8.996270221204689e-07
# R= 0.6344765299733098
# Es= 1.9503181371302556
# 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503400877966
#             Iterations: 134
#             Function evaluations: 5277
#             Gradient evaluations: 134
# 8.56747940586811e-08
# R= 0.6253841038524143
# Es= 1.992011573256344
# 36
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503560534491
#             Iterations: 65
#             Function evaluations: 2868
#             Gradient evaluations: 65
# 4.895181920024624e-08
# R= 0.6235153620862934
# Es= 1.9990027508003534
# 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503684563224
#             Iterations: 9
#             Function evaluations: 475
#             Gradient evaluations: 9
# 3.8028084574290855e-08
# R= 0.623526761008125
# Es= 1.9990118202367675
# 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615038437686074
#             Iterations: 36
#             Function evaluations: 1867
#             Gradient evaluations: 36
# 4.881349182825912e-08
# R= 0.6236747780398499
# Es= 1.9981029804432788
# 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61503960370333
#             Iterations: 25
#             Function evaluations: 1415
#             Gradient evaluations: 25
# 3.575090853595407e-08
# R= 0.6241278314442048
# Es= 1.9974323893519572
# 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61504059423688
#             Iterations: 6
#             Function evaluations: 385
#             Gradient evaluations: 6
# 3.037045370262487e-08
# R= 0.6241321386488129
# Es= 1.9974072060264154
# 56
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61504159115823
#             Iterations: 13
#             Function evaluations: 867
#             Gradient evaluations: 13
# 3.056630722024829e-08
# R= 0.6242277631872335
# Es= 1.9971641180087714
# 60
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61504112056967
#             Iterations: 13
#             Function evaluations: 919
#             Gradient evaluations: 13
# 1.4428574582817534e-08
# R= 0.6242165218298654
# Es= 1.997071268581065
# 64
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61504100164874
#             Iterations: 8
#             Function evaluations: 623
#             Gradient evaluations: 8
# 3.646198989990744e-09
# R= 0.6242152023648441
# Es= 1.997068553755632
# 68
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615040876521356
#             Iterations: 4
#             Function evaluations: 330
#             Gradient evaluations: 4
# 3.836493284792959e-09
# R= 0.6242148461369621
# Es= 1.9970699274152386
# 72
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61504083833535
#             Iterations: 12
#             Function evaluations: 1002
#             Gradient evaluations: 12
# 1.1708097857694364e-09
# R= 0.6242417975143696
# Es= 1.9970135115540977
# 76
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615040740735935
#             Iterations: 2
#             Function evaluations: 185
#             Gradient evaluations: 2
# 2.992466319552939e-09
# R= 0.6242432550741353
# Es= 1.9970134123200067
# 80
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615040646635364
#             Iterations: 17
#             Function evaluations: 1575
#             Gradient evaluations: 17
# 2.885189432661236e-09
# R= 0.6240566875433187
# Es= 1.9970780715086018
# 84
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615040724978314
#             Iterations: 31
#             Function evaluations: 2879
#             Gradient evaluations: 31
# 2.402049739994593e-09
# R= 0.6239287906048879
# Es= 1.9954164835771295
# 88
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61504072493805
#             Iterations: 1
#             Function evaluations: 105
#             Gradient evaluations: 1
# 1.2345977788305108e-12
# R= 0.623918881752309
# Es= 1.9954250429968954
# 92
# 0.5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.615001873156565
#             Iterations: 84
#             Function evaluations: 2972
#             Gradient evaluations: 84
# 33.615001873156565
# R= 7.720347017370947
# Es= 4.127454184903283
# 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61505917581377
#             Iterations: 73
#             Function evaluations: 2905
#             Gradient evaluations: 73
# 1.7569417112719417e-06
# R= 10.507163088514227
# Es= 4.412184043702403
# 37
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.616612388862094
#             Iterations: 108
#             Function evaluations: 5160
#             Gradient evaluations: 108
# 4.7622573362581235e-05
# R= 14.999251639758693
# Es= 4.812642626366372
# 45
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61661546252261
#             Iterations: 17
#             Function evaluations: 1034
#             Gradient evaluations: 17
# 9.423604385383125e-08
# R= 21.19322071212709
# Es= 5.223488972264305
# 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61662010663214
#             Iterations: 11
#             Function evaluations: 894
#             Gradient evaluations: 11
# 1.4238477735533696e-07
# R= 31.88792658780241
# Es= 5.801836328362048
# 74
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61662850912358
#             Iterations: 8
#             Function evaluations: 915
#             Gradient evaluations: 8
# 2.57613799687416e-07
# R= 48.99297219702994
# Es= 6.466257633630242
# 107
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61664837296176
#             Iterations: 9
#             Function evaluations: 1657
#             Gradient evaluations: 9
# 6.090095479255933e-07
# R= 0.46496438173659066
# Es= 3.219491375835388
# 177
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.6166476247086
#             Iterations: 4
#             Function evaluations: 765
#             Gradient evaluations: 4
# 2.2940835482593068e-08
# R= 0.46495406273236356
# Es= 3.2195999075792785
# 181
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61664732361889
#             Iterations: 2
#             Function evaluations: 394
#             Gradient evaluations: 2
# 9.231166535587074e-09
# R= 0.4649419082696401
# Es= 3.2197046380845227
# 185
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61664712904594
#             Iterations: 5
#             Function evaluations: 996
#             Gradient evaluations: 5
# 5.9654492735152295e-09
# R= 0.46492991720502685
# Es= 3.2198121045300625
# 189
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.616646931853666
#             Iterations: 3
#             Function evaluations: 613
#             Gradient evaluations: 3
# 6.045755427294571e-09
# R= 0.4649177757399508
# Es= 3.219916735804202
# 193
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.616646759757465
#             Iterations: 3
#             Function evaluations: 623
#             Gradient evaluations: 3
# 5.276330235938912e-09
# R= 0.464905682870333
# Es= 3.220021102234632
# 197
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.616646568458215
#             Iterations: 3
#             Function evaluations: 634
#             Gradient evaluations: 3
# 5.865080234258198e-09
# R= 0.46489365175028646
# Es= 3.2201255553510357
# 201
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61680758691507
#             Iterations: 27
#             Function evaluations: 5649
#             Gradient evaluations: 27
# 4.9366956385206e-06
# R= 0.46553136031780595
# Es= 3.209356262910982
# 205
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.61680746922473
#             Iterations: 5
#             Function evaluations: 1087
#             Gradient evaluations: 5
# 3.6082728426027443e-09
# R= 0.4655321663875644
# Es= 3.209459409242306
# 209
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -32.6168074707779
#             Iterations: 9
#             Function evaluations: 1998
#             Gradient evaluations: 9
# 4.761864759866894e-11
# R= 0.46552674912028685
# Es= 3.2095566284982473
# 213
